# %% [markdown]
# # Read in data

# %%
import pandas as pd
import numpy as np
from itertools import product, combinations
import os
import sys
import seaborn as sns
import matplotlib.pyplot as plt
from pylatexenc.latexencode import unicode_to_latex as text2latex
import cmcrameri.cm as cmc


sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath('__file__'))))

from src.helpers import make_aesthetic, cat_stats
import random


mypal = make_aesthetic()

random.seed(42)
np.random.seed(42)

def make_bold(x):
    words = x.split()
    words = ' \\ '.join([w for w in words])  # Escape backslash properly
    bold_str = f"$\\bf{{{words}}}$"  # Correctly format the f-string
    return bold_str

def to_number(s):
    s = str(s)
    s = s.replace(",", "")
    return float(s) if s else np.nan

def read_data(filter_final=False):
    df = pd.read_csv("../data/clean/ssl.csv")
    if filter_final:
        df = df[df['Final'] == 1]
    df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
    df['Proportion'] = df['Proportion'].apply(to_number)
    df['Relavent_N'] = df['N'].apply(to_number)
    df['N'] = df['N'].apply(to_number)
    df['Study'] = df['Title']
    assert df['Proportion'].notna().all(), "Proportion column contains NaN values"
    assert df['N'].notna().all(), "N column contains NaN values"
    df = df.dropna(subset=['Date', 'Proportion', 'N'])
    df['disagree'] = (df['JA Annot'] != df['AP Annot']).astype(int)
    df['unanimous'] = df['disagree'].apply(lambda x: 0 if x else 1)
    df.index = range(len(df))  # Reset index after dropping rows
    return df
    
df = read_data()
print(df['Proportion'].describe())

print(df)
# Out:
# count    25.000000
# mean      0.285279
# std       0.117025
# min       0.130000
# 25%       0.220000
# 50%       0.276000
# 75%       0.350000
# max       0.660000
# Name: Proportion, dtype: float64
#    Person            Source  \
# 0      JA  Consumer Reports
# 1      JA  Consumer Reports
# 2      JA  Consumer Reports
# 3      JA           Rutgers
# 4      JA           Rutgers
# 5      JA           Rutgers
# 6      JA           Rutgers
# 7      JA              NBER
# 8      JA              NBER
# 9      JA   Elon University
# 10     JA   Elon University
# 11     JA   Elon University
# 12     JA   Elon University
# 13     JA   Elon University
# 14     JA   Elon University
# 15     JA   Elon University
# 16     JA   Elon University
# 17     JA               Pew
# 18     AP     Neuron Expert
# 19     JA             IPSOS
# 20     JA             IPSOS
# 21     JA             IPSOS
# 22     JA             IPSOS
# 23     JA             IPSOS
# 24     JA             IPSOS
#
# ...

# %% [markdown]
# # Agreement

# %%
# Print agreement stats
######################
######################



df2 = read_data(filter_final=False)
# Index(['Person', 'Source', 'Kind', 'Country', 'Title', 'Date', 'URL',
#        'Question Page Number', 'Question Text', 'N', 'Proportion',
#        'Relavent_N', 'Note', 'Exact Sample', 'JA Annot', 'AP Annot',
#        'Init Disagre', 'Final', 'Study', 'disagree', 'unanimous'],
#       dtype='object')

df2['Annotation'] = df2['unanimous'].apply(lambda x: "Unanimous" if x == 1 else "Disagree")
total_annotations = len(df2)

unanimous_count = df2['unanimous'].sum()
disagree_count = df2['disagree'].sum()
unanimous_percentage = (unanimous_count / total_annotations) * 100
disagree_percentage = (disagree_count / total_annotations) * 100
annotation_str = f"""
Out of {total_annotations} tasks, there were {unanimous_count} agreements ({unanimous_percentage:.0f}%) and {disagree_count} disagreements ({disagree_percentage:.0f}%).
"""

print(text2latex(annotation_str))




# Perm test on if props differ
######################
######################
from scipy.stats import permutation_test
sns.stripplot(x='Annotation', y='Proportion', data=df2, palette=["#2C3531", "#D41876"])
def perm_mean(x, y, axis):
    return np.mean(x, axis=axis) - np.mean(y, axis=axis)

x = df2[df2['unanimous'] == 1]['Proportion'].to_numpy()
y = df2[df2['unanimous'] == 0]['Proportion'].to_numpy()
res = permutation_test((x, y), perm_mean, vectorized=True,
                       n_resamples=10*1000, random_state=42)
print(text2latex(f"Prevalence for unanimous (M={np.mean(x):.2f}, SD={np.std(x):.2f}) and non-unanimous (M={np.mean(y):.2f}, SD={np.std(y):.2f}) tasks did not differ, p={res.pvalue:.3f} from permutation test with 10K iterations."))
# Out:
# Out of 25 tasks, there were 21 agreements (84\%) and 4 disagreements (16\%).
#
# Prevalence for unanimous (M=0.28, SD=0.12) and non-unanimous (M=0.32, SD=0.04) tasks did not differ, p=0.501 from permutation test with 10K iterations.
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_43564/1533275422.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Annotation', y='Proportion', data=df2, palette=["#2C3531", "#D41876"])

# %% [markdown]
# # Simulations

# %% [markdown]
# ## Test Underlying Logic

# %%
def get_estimators():
    return {
        'sample_mean': lambda probs: np.mean(probs),
        'observed_max': lambda probs: np.max(probs),
        'second_largest': lambda probs: np.sort(probs)[::-1][1] if len(probs) > 1 else probs[0],
        'third_largest': lambda probs: np.sort(probs)[::-1][2] if len(probs) > 2 else np.sort(probs)[::-1][-1],
        'median': lambda probs: np.median(probs)
    }



def run_simulation_test(n_events=21, sample_size=10000, n_sims=10000):
    """Run simulation and return results"""
    np.random.seed(42)
    estimators = get_estimators()
    results = {name: [] for name in estimators.keys()}
    results['true_max'] = []
    
    for _ in range(n_sims):
        true_probs = np.random.beta(2, 2, n_events)
        
        assert len(true_probs) == n_events, "True probabilities length mismatch"
        assert np.all((true_probs >= 0) & (true_probs <= 1)), "True probabilities out of bounds"
        
        true_max = np.max(true_probs)
        assert 0 <= true_max <= 1, "True max out of bounds"
        
        
        binomial_realizations = np.random.binomial(sample_size, true_probs) 
        assert len(binomial_realizations) == n_events, "Binomial realizations length mismatch"
        assert np.all((binomial_realizations >= 0) & (binomial_realizations <= sample_size)), "Binomial realizations out of bounds"
        observed_probs = binomial_realizations / sample_size
        assert len(observed_probs) == n_events, "Observed probabilities length mismatch"
        
        results['true_max'].append(true_max)
        for name, estimator in estimators.items():
            results[name].append(estimator(observed_probs))
    
    return pd.DataFrame(results)

run_simulation_test()
print("We passed :)")
# Out:
# We passed :)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Apply aesthetic settings
make_aesthetic(font_scale=1.5)

def clean_text(text):
    """Clean text for LaTeX compatibility."""
    return text.replace('_', " ")

def run_simulation(n_events=21, sample_size=10000, n_sims=10000, beta_type='symmetric'):
    """Run simulation and return results."""
    np.random.seed(42)
    estimators = get_estimators()
    results = {name: [] for name in estimators.keys()}
    results['true_max'] = []
    
    for _ in range(n_sims):
        # Generate true probabilities based on beta type
        if beta_type == 'symmetric':
            true_probs = np.random.beta(2, 2, n_events)
        elif beta_type == 'skewed':
            true_probs = np.random.beta(1, 3, n_events)
        
        true_max = np.max(true_probs)
        observed_probs = np.random.binomial(sample_size, true_probs) / sample_size
        
        results['true_max'].append(true_max)
        for name, estimator in estimators.items():
            results[name].append(estimator(observed_probs))
    
    # Convert results to DataFrame
    df = pd.DataFrame(results)
    df['beta_type'] = beta_type
    return df

def analyze_results(df):
    """Analyze simulation results and calculate metrics."""
    estimators = [col for col in df.columns if col not in ['true_max', 'beta_type']]
    results = []
    
    for est in estimators:
        bias = np.mean(df[est] - df['true_max'])
        variance = np.var(df[est])
        rmse = np.sqrt(np.mean((df[est] - df['true_max'])**2))
        pct_too_high = np.mean(df[est] > df['true_max']) * 100
        pct_too_low = np.mean(df[est] < df['true_max']) * 100
        
        results.append({
            'Estimator': clean_text(est),
            'Beta Type': df['beta_type'].iloc[0],
            'Bias': bias,
            'Variance': variance,
            'RMSE': rmse,
            'Percent Too High': pct_too_high,
            'Percent Too Low': pct_too_low
        })
    
    return pd.DataFrame(results)

def plot_results(df):
    """Visualize simulation results."""
    estimators = [col for col in df.columns if col not in ['true_max', 'beta_type']]
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
    
    # Boxplot of estimation errors
    errors = {est: df[est] - df['true_max']  for est in estimators}
    ax1.boxplot(errors.values(), labels=errors.keys())
    ax1.axhline(y=0, color='red', linestyle='--', alpha=0.7)
    ax1.set_ylabel('Estimate - True Max')
    ax1.set_title('Estimation Errors')
    ax1.tick_params(axis='x', rotation=45)
    
    # Scatter plot of true vs estimated values
    colors = plt.cm.tab10(np.linspace(0, 1, len(estimators)))
    for i, est in enumerate(estimators):
        ax2.scatter(df['true_max'], df[est], alpha=0.6, 
                    label=clean_text(est), color=colors[i], s=20)
    
    ax2.plot([0, 1], [0, 1], 'k--', alpha=0.7)
    ax2.set_xlabel('True Maximum')
    ax2.set_ylabel('Estimated Maximum')
    ax2.set_title('True vs Estimated')
    ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    
    plt.tight_layout()
    plt.show()

# Run the simulation and analyze results
summary_dfs = []
raw_dfs = []
beta_types = ['symmetric', 'skewed']
for beta_type in beta_types:
    simulation_df = run_simulation(beta_type=beta_type)
    raw_dfs.append(simulation_df)
    summary_df = analyze_results(simulation_df)
    summary_df.to_latex(f"../tables/{beta_type}_estimation_methods.tex", index=False, escape=False, float_format="%.3f")
    summary_dfs.append(summary_df)
    plot_results(simulation_df)
    
# Pooled 
pooled_df = pd.concat(raw_dfs, ignore_index=True)
plot_results(pooled_df)
pooled_summary_df = analyze_results(pooled_df)
pooled_summary_df['Beta Type'] = "pooled"
pooled_summary_df.to_latex("../tables/pooled_estimation_methods.tex", index=False, escape=False, float_format="%.3f")

# Concats skewed and sym
concat_summary_df = pd.concat(summary_dfs, ignore_index=True)
concat_summary_df = pd.concat([concat_summary_df, pooled_summary_df], ignore_index=True)
concat_summary_df.to_latex("../tables/concat_estimation_methods_summary.tex", index=False, escape=False, float_format="%.3f", 
                           label="estimation_methods_summary",
                           caption="Summary of estimation methods. Skewed is Beta (1,3),  symmetric is Beta (2,2), and pooled is all trials.",)

# Read and process raw data
df = read_data()
raw_data = sorted(df['Proportion'].to_list())
print("Second largest proportion:", raw_data[-2])
# Out:
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_42415/1519788605.py:70: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax1.boxplot(errors.values(), labels=errors.keys())
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_42415/1519788605.py:88: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_42415/1519788605.py:70: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax1.boxplot(errors.values(), labels=errors.keys())
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_42415/1519788605.py:88: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# ...

# %% [markdown]
# ## Round for MS

# %%
def print_small_vals(val, digits=2):
    if abs(val) > 0.001:
        return round(val, digits)
    else:
        return f"{val:.1e}"

pooled_summary_df['rounded_bias'] = pooled_summary_df['Bias'].apply(print_small_vals)
pooled_summary_df['rounded_varaience'] = pooled_summary_df['Variance'].apply(print_small_vals)

display(pooled_summary_df)
# Out:
#         Estimator Beta Type      Bias  Variance      RMSE  Percent Too High  \
# 0     sample mean    pooled -0.406989  0.017598  0.415938             0.000
# 1    observed max    pooled  0.000088  0.018807  0.003873            51.185
# 2  second largest    pooled -0.084236  0.022791  0.113778             0.840
# 3   third largest    pooled -0.143520  0.025218  0.170362             0.005
# 4          median    pooled -0.426761  0.024854  0.440615             0.000
#
#    Percent Too Low rounded_bias  rounded_varaience
# 0          100.000        -0.41               0.02
# 1           48.815      8.8e-05               0.02
# 2           99.160        -0.08               0.02
# 3           99.995        -0.14               0.03
# 4          100.000        -0.43               0.02

# %% [markdown]
# # Multiverse

# %%
import pandas as pd
import numpy as np
from itertools import product, combinations
# Compute weighted mean and std
def compute_weighted_mean(proportions, weights):
    avg = np.average(proportions, weights=weights)
    std = np.sqrt(np.average((proportions - avg)**2, weights=weights))
    return avg, std

# Weighting logic
def weight_updated(method, df_subset):
    if method == 'no_weighting':
        weights = np.ones(len(df_subset))
    elif method == 'sample_size':
        weights = df_subset['N']
    elif method in ['recency_fast_decay', 'recency_slow_decay']:
        reference_date = pd.to_datetime("2025-07-10")  # Current date - adjust as needed
        
        # Calculate days from reference date
        df_dates = pd.to_datetime(df_subset['Date'])
        days_from_ref = (reference_date - df_dates).dt.days
        
        days_from_ref = np.maximum(days_from_ref, 0)
        
        # Different decay rates for fast vs slow
        if method == 'recency_fast_decay':
            weights = np.exp(-0.01 * days_from_ref)
        else:  # recency_slow_decay
            # Slow decay: recent data preferred but older data still has reasonable weight
            weights = np.exp(-0.001 * days_from_ref)
    else:
        raise ValueError(f"Unknown weighting method: {method}")
    return compute_weighted_mean(df_subset['Proportion'], weights)

# Survey-level averaging
def apply_survey_macro_averaging(df_subset):
    return df_subset.groupby('Title').agg({
        'N': "mean",
        'Proportion': 'mean',
        'Date': 'first'
    }).reset_index()

# Generate all combinations of rows to drop
def all_combinations(lst, subset_len):
    return [list(c) for c in combinations(lst, subset_len)]

# Main multiverse run
def run_multiverse(df):
    d1_options = [False, True]
    d2_options = ['no_weighting', 'sample_size', 'recency_fast_decay', 'recency_slow_decay']
    d3_options = ["all", "unanimous", "consensus-coding"]
    multiverse_results = []
    for d1, d2, d3 in product(d1_options, d2_options, d3_options):
        try:

            if d3=="unanimous":
                df_subset = df[df['unanimous'] == 1].copy()
            elif d3=="consensus-coding":
                df_subset = df[df['Final'] == 1].copy()
            elif d3 =="all":
                df_subset = df.copy()


            if d1:
                df_subset = apply_survey_macro_averaging(df_subset)
            else:
                df_subset = df_subset.copy()


            mean, sd = weight_updated(d2, df_subset)
            multiverse_results.append({
                'survey_avg': 'macro' if d1 else 'raw',
                'question_weighting': d2,
                'agreement': d3,
                'Mean': mean,
                'SD': sd
            })
        except Exception as e:
            multiverse_results.append({
                'survey_avg': 'macro' if d1 else 'raw',
                'question_weighting': d2,
                'Mean': None,
                'SD': None,
                'agreement': d3,
                'Error': str(e)
            })
    return pd.DataFrame(multiverse_results)

# Initial multiverse
df = read_data(filter_final=False)
multiverse_df = run_multiverse(df)
multiverse_df['dropped'] = 'none'
multiverse_df['did_drop'] = "no_dropping"

# Drop-2 analyses
rows = range(len(df))
all_combos = list(combinations(rows, 2))
dropped_dfs = []
for combo in all_combos:
    temp_df = df.drop(index=list(combo)).reset_index(drop=True)
    temp_multiverse = run_multiverse(temp_df)
    temp_multiverse['dropped'] = str(combo)
    temp_multiverse["did_drop"] = "leave_2_out"
    dropped_dfs.append(temp_multiverse)

drop_df = pd.concat(dropped_dfs, ignore_index=True)
full_data = pd.concat([multiverse_df, drop_df], ignore_index=True)

full_data = pd.concat([multiverse_df, drop_df], ignore_index=True)

# Summary
total_responses = df['N'].sum() 
total_n = df.groupby(by=['Title'])['N'].mean().reset_index()['N'].sum()
means = full_data['Mean'].dropna().to_list()
desc_str = f"{int(total_n):,} participants, {int(total_responses):,} responses, {len(means):,} analyses"
print(desc_str)
# Out:
# 16,253 participants, 42,394 responses, 7,224 analyses

# %% [markdown]
# # Histogram plot

# %%
print(desc_str)
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

#################
# CONFIGS

plt.figure(figsize=(12, 6))
make_aesthetic(font_scale=2)
line_color = 'black'
linewidth=3.5
##################



raw_mean = df['Proportion'].mean()


mean_val = np.mean(means)
q25, q75 = np.percentile(means, [25, 75])
lower, upper = np.percentile(means, [2.5, 97.5])

iqr = f"[{q25:.2f}-{q75:.2f}]"
ci = f"[{lower:.2f}-{upper:.2f}]"

print("mean", f"{mean_val:.2f}")
print("raw mean", f"{raw_mean:.2f}")
print("iqr", iqr)
print("ci", ci)


# basic histplot
full_data['Sample Size Weighted'] = full_data['question_weighting'].apply(lambda x: "Yes" if x == 'sample_size' else "No")
full_data['Sample Size Weighted'] = full_data['question_weighting'].apply(lambda x: "Yes" if x == 'sample_size' else "No")

# Filter data
no_weight = full_data[full_data['Sample Size Weighted'] == 'No']['Mean']
yes_weight = full_data[full_data['Sample Size Weighted'] == 'Yes']['Mean']


sns.histplot(
    no_weight, bins=50, kde=False,
    color="white", edgecolor="black", alpha=1.0,
    label="Sample Size\nWeighted: No",
    hatch="///"   # diagonal stripes
)
sns.histplot(
    yes_weight, bins=50, kde=False,
    color="lightgray", edgecolor="black", alpha=1.0,
    label="Sample Size\nWeighted: Yes",
    hatch="\\\\\\"   # opposite diagonal stripes
)

# spans and lines with labels
plt.axvspan(lower, upper, color='gray', alpha=0.2,
            label=f"95% CI\n{ci}", edgecolor='gray')
plt.axvspan(q25, q75, color=mypal[3], alpha=0.5, label=f"IQR\n{iqr}")
plt.axvline(raw_mean, color=line_color, linestyle='solid', linewidth=linewidth,
            label=f"Raw Data\nMean = {raw_mean:.2f}")
plt.axvline(mean_val, color=line_color, linestyle='--', linewidth=linewidth,
            label=f"Multiverse\nMean = {mean_val:.2f}")
multiverse_sample_weighted_mean = np.mean(yes_weight)
plt.axvline(multiverse_sample_weighted_mean, color=line_color, linestyle='dotted',
            linewidth=linewidth, label=f"Multiverse\nSample Weighted\nMean: {multiverse_sample_weighted_mean:.2f}")

# split legends into two groups
handles, labels = plt.gca().get_legend_handles_labels()
group1 = (handles[:2], labels[:2])   # hist categories
group2 = (handles[2:], labels[2:])   # CI + means

leg1 = plt.legend(*group1, frameon=False, fontsize=15,
                  loc="upper left", bbox_to_anchor=(-0.02, 1.1))
leg2 = plt.legend(*group2, frameon=False, fontsize=15,
                  loc="upper right", bbox_to_anchor=(1.02, 1.1))
plt.gca().add_artist(leg1)

# labels/titles
plt.title(f"{make_bold('Distribution of SSL Task Prevalence Estimates')}\n{desc_str}")
plt.xlabel("Estimated Task Prevalence from Multiverse Analyses")
plt.ylabel("Frequency")
sns.despine()
plt.tight_layout()
plt.savefig("../plots/prev_hist.pdf", dpi=300, bbox_inches='tight')
plt.show()


print("COPY PASTE TO LATEX")
result_str = f"{mean_val:.0%}, 95% CI = [{lower:.0%}, {upper:.0%}], IQR = [{q25:.0%}, {q75:.0%}]"
print(text2latex(result_str))
# Out:
# 16,253 participants, 42,394 responses, 7,224 analyses
# mean 0.29
# raw mean 0.29
# iqr [0.28-0.30]
# ci [0.26-0.32]
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_42415/1872804403.py:56: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.axvspan(lower, upper, color='gray', alpha=0.2,
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_42415/1872804403.py:83: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# COPY PASTE TO LATEX
# 29\%, 95\% CI = [26\%, 32\%], IQR = [28\%, 30\%]

# %% [markdown]
# # Some manual looks at multiverse universe

# %%
import seaborn as sns
import matplotlib.pyplot as plt


full_data2 = full_data.copy()
full_data2['Recency Weighted'] = full_data2['question_weighting'].apply(lambda x: "Yes" if x in ['recency_fast_decay', 'recency_slow_decay'] else "No")
full_data2['Sample Size Weighted'] = full_data2['question_weighting'].apply(lambda x: "Yes" if x == 'sample_size' else "No")
full_data2['Agreement'] = full_data2['agreement'].apply(lambda x: x.title())

# Plot 1: Recency Weighted
plt.figure(figsize=(6, 6))
sns.histplot(
    full_data2,
    x='Mean',
    hue='Recency Weighted',
    palette=mypal[1:4],
    alpha=0.7,
)
plt.xlabel("Estimated Average Task Prevalence")
plt.ylabel("Count")
plt.title("Recency Weighted")
plt.tight_layout()
plt.savefig("../plots/recency_weighted_hist.pdf", dpi=300, bbox_inches='tight')
plt.close()

# Plot 2: Agreement
plt.figure(figsize=(6, 6))
sns.histplot(
    full_data2,
    x='Mean',
    hue='Agreement',
    palette=mypal[1:6],
    alpha=0.7,
)
plt.xlabel("Estimated Average Task Prevalence")
plt.ylabel("Count")
plt.title("Agreement")
plt.tight_layout()
plt.savefig("../plots/agreement_hist.pdf", dpi=300, bbox_inches='tight')
plt.close()

# Plot 3: Sample Size Weighted
plt.figure(figsize=(6, 6))
sns.histplot(
    full_data2,
    x='Mean',
    hue='Sample Size Weighted',
    palette=mypal[0:6],
    alpha=0.7,
)
plt.xlabel("Estimated Average Task Prevalence")
plt.ylabel("Count")
plt.title("Sample Size Weighted")
plt.tight_layout()
plt.savefig("../plots/sample_size_weighted_hist.pdf", dpi=300, bbox_inches='tight')
plt.close()

# Combined plot
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=False)

sns.histplot(
    full_data2,
    x='Mean',
    hue='Recency Weighted',
    palette=mypal[0:6],
    alpha=0.7,
    ax=axes[0]
)
axes[0].set_xlabel("Estimated Average Task Prevalence")
axes[0].set_ylabel("Count")
axes[0].set_title("Recency Weighted")

sns.histplot(
    full_data2,
    x='Mean',
    hue='Agreement',
    palette=mypal[0:6],
    alpha=0.7,
    ax=axes[1]
)
axes[1].set_xlabel("Estimated Average Task Prevalence")
axes[1].set_title("Agreement")

sns.histplot(
    full_data2,
    x='Mean',
    hue='Sample Size Weighted',
    palette=mypal[0:6],
    alpha=0.7,
    ax=axes[2]
)
axes[2].set_xlabel("Estimated Average Task Prevalence")
axes[2].set_title("Sample Size Weighted")

plt.tight_layout()
plt.savefig("../plots/multiverse_histograms_row.pdf", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_42415/4068324796.py:12: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.histplot(
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_42415/4068324796.py:22: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_42415/4068324796.py:28: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.histplot(
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_42415/4068324796.py:38: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_42415/4068324796.py:44: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.histplot(
# ...

# %% [markdown]
# # Sensitivity analysis

# %%
import numpy as np
import matplotlib.pyplot as plt

mypal = make_aesthetic()
print(mypal)

posterior_samples = np.array(means)
null_values = np.linspace(0.10, 0.40, 1000)
probs = [(posterior_samples > null).mean() for null in null_values]

plt.figure(figsize=(12, 8))
plt.plot(null_values, probs, color='black', lw=2)

threshold_specs = [
    (0.99, mypal[2], "Prob > 0.99"),
    (0.80, mypal[1], "Prob > 0.80"),
    (0.60, mypal[3], "Prob > 0.60"),
    (0.50, "gray",   "Prob > 0.50"),
]

for thresh, col, lbl in threshold_specs:
    # draw the horizontal line
    plt.axhline(thresh, linestyle='-', color=col, label=lbl)

    idxs = np.where(np.array(probs) >= thresh)[0]
    if len(idxs):                      
        x_star = null_values[idxs[-1]]  
        plt.text(x_star + 0.01, thresh, f"{x_star:.2f}",
                 color=col, ha='center', va='bottom', fontsize=14)
# ---------------------------------------------------------------------------


plt.xlabel("Hypothesized Prevalence")
plt.ylabel("Prob (Estimate > Hypothesis)")
plt.title(
    f"{make_bold('Prob. SSL Task Prevalence Estimate Exceeds Value')}\n"
    "Probability that a specification from the multiverse yields a\npoint estimate above the "
    "prevalence threshold"
)
plt.legend(frameon=False, fontsize=14, loc="lower left")
plt.ylim(0, 1.05)
plt.tight_layout()
plt.savefig("../plots/prev_sensitivity.pdf", dpi=300, bbox_inches='tight')

plt.show()
# Out:
# ['#A9A9A9', '#D41876', '#020887', '#89DAFF', '#F18805', '#826AED', '#342E37', '#D4B2D8', '#00A896', '#7DCD85', '#E3B505', '#F7B2AD', '#F45B69', '#E87461', '#7E6551']
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_42415/2717495112.py:42: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# # Predictors of estimates in multiverse

# %%
import statsmodels.formula.api as smf
from src.statsmodels_handler import StatsmodelsHandler, clean_var_name_from_formula

make_aesthetic(font_scale=2.3)
    
full_data['Mean100'] = full_data['Mean']*100
mod = smf.ols(formula='Mean100 ~ C(question_weighting, Treatment(reference="no_weighting")) + C(agreement, Treatment(reference="all")) + C(survey_avg, Treatment(reference="raw")) + '
                      'C(did_drop, Treatment(reference="no_dropping"))', data=full_data).fit()

handler = StatsmodelsHandler(model=mod)
ax = handler.plot(figsize=(12,8),
                  clean_var_name = clean_var_name_from_formula)

for pp in [-1, 1, 2, 3]:
    plt.axvline(x=pp, color='gray', linestyle='dashed', linewidth=1, alpha=0.7, label="-1 percentage points")



plt.xlabel("Coefficient (Percentage Points) and 95% CIs")
plt.ylabel("Analysis Option")

full_title = "Effect of Analysis Choices on Estimated Task Prevalence"
print(full_title)

plt.title(full_title, x=-1, fontweight='bold')
# plt.grid(alpha=1, linewidth=1)
plt.savefig("../plots/prev_multiverse_regression.pdf", dpi=300, bbox_inches='tight')


handler.to_latex()

display(mod.summary())
# Out:
# Effect of Analysis Choices on Estimated Task Prevalence
# Intercept: $\beta = 28.58$, $SE = 0.17$, $p <0.001$, $95\% CI = [28.25, 28.90]$
# C(question\_weighting, Treatment(reference="no\_weighting"))[T.recency\_fast\_decay]: $\beta = 0.65$, $SE = 0.03$, $p <0.001$, $95\% CI = [0.60, 0.71]$
# C(question\_weighting, Treatment(reference="no\_weighting"))[T.recency\_slow\_decay]: $\beta = 0.75$, $SE = 0.03$, $p <0.001$, $95\% CI = [0.70, 0.80]$
# C(question\_weighting, Treatment(reference="no\_weighting"))[T.sample\_size]: $\beta = 3.49$, $SE = 0.03$, $p <0.001$, $95\% CI = [3.44, 3.55]$
# C(agreement, Treatment(reference="all"))[T.consensus-coding]: $\beta = -0.56$, $SE = 0.02$, $p <0.001$, $95\% CI = [-0.61, -0.52]$
# C(agreement, Treatment(reference="all"))[T.unanimous]: $\beta = -0.25$, $SE = 0.02$, $p <0.001$, $95\% CI = [-0.30, -0.21]$
# C(survey\_avg, Treatment(reference="raw"))[T.macro]: $\beta = -0.72$, $SE = 0.02$, $p <0.001$, $95\% CI = [-0.75, -0.68]$
# ...

# %%
# make sure we are getting back actual raw estimates
raw_con_from_multi = full_data.query("survey_avg == 'raw' and question_weighting == 'no_weighting' and did_drop == 'no_dropping' and agreement=='all'")['Mean'].mean()
raw_con_from_raw = df['Proportion'].mean()
assert raw_con_from_multi == raw_con_from_raw, "Raw control from multiverse does not match raw data mean!"

# %% [markdown]
# # Raw data analysis

# %%
df['year'] = df['Date'].dt.year
sns.swarmplot(x='year', y='Proportion', data=df, palette=cmc.glasgow, hue='N', s=10)
sns.barplot(x='year', y='Proportion', data=df, color='gray', alpha=0.8, err_kws={'alpha':0.3})
plt.legend(title='Sample Size', bbox_to_anchor=(1, 1), loc='upper left')
plt.title("Raw Estimates by Year and Sample Size")
plt.show()

# %% [markdown]
# #  OLS and Trends

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import pearsonr
import cmcrameri.cm as cmc


mypal = make_aesthetic()


# Convert dates to days since start
df['days_since_start'] = (df['Date'] - df['Date'].min()).dt.days

# Set up regression data
X = sm.add_constant(df['days_since_start'])
y = df['Proportion']

# Fit unweighted OLS with clustered standard errors by survey
model = sm.OLS(y, X).fit(
    cov_type='cluster',
    cov_kwds={'groups': df['Title']}
)

# Calculate correlation and p-value
rho, rho_pvalue = pearsonr(df['days_since_start'], df['Proportion'])

# Print results nicely formatted
print("\n" + "="*80)
print(" " * 30 + "OLS REGRESSION RESULTS")
print("="*80)

print(f"\nDATA OVERVIEW")
print(f"Sample size: {len(df)} observations")
print(f"Time span: {(df['Date'].max() - df['Date'].min()).days} days")
print(f"Raw correlation (ρ): {rho:.2f} (p = {rho_pvalue:.2f})")

print(f"\nOLS REGRESSION RESULTS")
print(f"   Daily change: {model.params[1]:.6f} ± {model.bse[1]:.6f}")
print(f"   Annual change: {model.params[1] * 365:.2f} percentage points/year")
print(f"   P-value: {model.pvalues[1]:.2f}")
print(f"   R-squared: {model.rsquared:.2f}")
print(f"   Intercept: {model.params[0]:.2f}")



# Create plot
plt.figure(figsize=(12, 6))

# Add time jitter for visualization
np.random.seed(42)
jitter_days = np.random.uniform(-10, 10, len(df))
date_jittered = df['Date'] + pd.to_timedelta(jitter_days, unit='D')

# Plot jittered points colored by sample size
scatter = plt.scatter(date_jittered, df['Proportion'],
                    c=df['N'], s=df['N']/5,
                    cmap=cmc.tokyo_r, alpha=0.7, edgecolors='black', linewidth=0.9)

plt.colorbar(scatter, label='Sample Size (N)')

# Create trend line
date_range = pd.date_range(df['Date'].min(), df['Date'].max(), freq='D')
days_range = (date_range - df['Date'].min()).days
X_pred = sm.add_constant(days_range)

# Calculate correlation for model
model_corr = np.sqrt(model.rsquared)

# OLS trend line
trend_y = model.predict(X_pred)
plt.plot(date_range, trend_y, 'b-', linewidth=3, alpha=0.8,
        label=f'OLS Regression Line (Pearson r={rho:.2f})',
         color=mypal[0])


# Add confidence intervals
pred_summary = model.get_prediction(X_pred)
conf_int = pred_summary.conf_int()
plt.fill_between(date_range, conf_int[:, 0], conf_int[:, 1],
                color=mypal[0], alpha=0.15, label='95% CI')

# Format plot
plt.xlabel('Date')
plt.ylabel('Task Prevalence')
plt.title('Average SSL Task Prevalence Over Time', fontweight='bold')
plt.legend(frameon=False, loc='upper left')
plt.xticks(rotation=45)
plt.savefig("../plots/prev_time_ols_regression.pdf", dpi=300)
plt.show()
# Out:
# ...
#                               OLS REGRESSION RESULTS
# ...
#
# DATA OVERVIEW
# Sample size: 25 observations
# Time span: 592 days
# Raw correlation (ρ): 0.44 (p = 0.03)
#
# OLS REGRESSION RESULTS
#    Daily change: 0.000284 ± 0.000112
#    Annual change: 0.10 percentage points/year
#    P-value: 0.01
#    R-squared: 0.20
#    Intercept: 0.17
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_42415/1522607306.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"   Daily change: {model.params[1]:.6f} ± {model.bse[1]:.6f}")
# ...

# %% [markdown]
# # cis

# %%
import numpy as np
import matplotlib.pyplot as plt

mypal = make_aesthetic(font_scale=2)
print(mypal)
samples = np.array(means)
bootstrap_probs = [0.99, 0.97, 0.95, 0.90, 0.85]


def bootstrap_ci(data, n_iterations=1000, ci=0.95):
    """Compute bootstrap confidence intervals."""
    n = len(data)
    indices = np.random.randint(0, n, (n_iterations, n))
    samples = data[indices]
    lower = np.percentile(samples, (1 - ci) / 2 * 100, axis=1)
    upper = np.percentile(samples, (1 + ci) / 2 * 100, axis=1)
    return np.mean(lower), np.mean(upper)


bootstrap_intervals = [bootstrap_ci(samples, n_iterations=1000, ci=prob) for prob in bootstrap_probs]
y_positions = list(range(len(bootstrap_probs), 0, -1))

plt.figure(figsize=(12, 8))

import matplotlib.pyplot as plt

for i, (ci, prob) in enumerate(zip(bootstrap_intervals, bootstrap_probs)):
    plt.hlines(y_positions[i], ci[0], ci[1], color=mypal[i % len(mypal)], linewidth=2, label=f"{int(prob * 100)}% CI")
    plt.text(ci[0], y_positions[i] + 0.1, f"{ci[0]:.3f}", ha='center', va='bottom', fontsize=22, color=mypal[i])
    plt.text(ci[1], y_positions[i] + 0.1, f"{ci[1]:.3f}", ha='center', va='bottom', fontsize=22, color=mypal[i])
    plt.axvline(x=np.mean(samples), color='black', linestyle='--', linewidth=1, alpha=0.07)

# Add label for the mean line
mean_val = np.mean(samples)
plt.text(mean_val + 0.009, y_positions[0] - 0.62, f"Mean: {mean_val:.2f}", ha='center', va='bottom', fontsize=22, color='gray')

# Add labels and aesthetics
plt.xlabel("Prevalence Range")
plt.yticks(y_positions, [f"{int(prob * 100)}% CI" for prob in bootstrap_probs])  # Label y-axis positions
plt.title(f"Bootstrap CIs of Average SSL Task Prevalence from Multiverse")
plt.tight_layout()
plt.savefig("../plots/prev_bootstrap_ci.pdf", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ['#A9A9A9', '#D41876', '#020887', '#89DAFF', '#F18805', '#826AED', '#342E37', '#D4B2D8', '#00A896', '#7DCD85', '#E3B505', '#F7B2AD', '#F45B69', '#E87461', '#7E6551']
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_42415/1578884984.py:41: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# # Percent Benchmarks

# %% [markdown]
# ## Summarize pop props

# %%
from datetime import datetime
from statsmodels.stats.proportion import proportion_confint

def format_row(row):
    """Format one row into a concise summary string with 95% CI."""
    source = row['Source']
    date_str = pd.to_datetime(row['Date']).strftime("%b-%-d-%Y")  # Jan-1-2025

    total = int(row['Eligible Possible N'])
    yes_prop = float(row['Eligible Proportion'])
    yes_count = int(round(total * yes_prop))

    # 95% CI for proportion
    ci_low, ci_upp = proportion_confint(yes_count, total, alpha=0.05, method="wilson")

    return (
        f"{source} ({date_str}, N={total}, "
        f"prevalence={yes_prop:.3f}, "
        f"95% CI [{ci_low:.2f}, {ci_upp:.2f}])"
    )

#####################
# Summarize props
#####################
df = read_data()
ppd = df[df['Eligible Flag (+1 means use)'] == 1].drop_duplicates(subset=['Title'])
ppd['pop_prop'] = ppd['Eligible Proportion'].astype(float)
ppd['date'] = ppd['Date']
sns.barplot(data=ppd, x='date', y='pop_prop')
most_recent = ppd.sort_values(by=['date'], ascending=False)
most_recent['Source'] = most_recent['Source'].apply(lambda x: "Rutgers University" if x == "Rutgers" else x)
all_strings = most_recent.apply(format_row, axis=1)
result_str = "\n".join(all_strings)
print(result_str)


#####################
# Most recent
#####################
row = most_recent.iloc[0]
total = int(row['Eligible Possible N'])
yes_prop = float(row['Eligible Proportion'])
yes_count = int(round(total * yes_prop))
ci_low, ci_upp = proportion_confint(yes_count, total, alpha=0.05, method="wilson")

most_recent_point = {
    "date": pd.to_datetime(row['Date']).strftime("%b-%-d-%Y"),
    "source": row['Source'],
    "N": total,
    "prevalence": yes_prop,
    "ci_low": ci_low,
    "ci_upp": ci_upp
}
print(most_recent_point)
# Out:
# Elon University (Jan-1-2025, N=500, prevalence=0.520, 95% CI [0.48, 0.56])
# Rutgers University (Oct-25-2024, N=4767, prevalence=0.530, 95% CI [0.52, 0.54])
# NBER (Aug-15-2024, N=9742, prevalence=0.396, 95% CI [0.39, 0.41])
# Consumer Reports (Aug-11-2023, N=2062, prevalence=0.310, 95% CI [0.29, 0.33])
# {'date': 'Jan-1-2025', 'source': 'Elon University', 'N': 500, 'prevalence': 0.52, 'ci_low': 0.47622345295527013, 'ci_upp': 0.5634715734262677}

# %% [markdown]
# ## Make benchmark plot

# %%
import textwrap
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def text_wrap(text, width=30):
    """Wrap text to a specified width."""
    try:
        return '\n'.join(textwrap.wrap(text, width=width))
    except Exception as e:
        return None

prop_max = df['Proportion'].max()
print(prop_max)
prev_est = most_recent_point['ci_low']
combined = prop_max * prev_est

bench = pd.read_csv("../data/clean/benchmarks.csv")
use = bench[bench['flag(positive)'] > 0]

# Create the plot
plt.figure(figsize=(12,9))

# Apply transformations
use['percentage'] = use['percentage'].apply(lambda x: np.round(combined * 100, 0) if x < 0 else x)
use = use.dropna(subset=['short_version'])
use['short_version_wrap'] = use['short_version'].apply(lambda x: text_wrap(x, width=30))
use = use.sort_values(by='percentage', ascending=False)

colors = [mypal[1] if "synthetic social learning" in row['short_version'] else mypal[0]
          for _, row in use.iterrows()]
ax = sns.barplot(x='percentage', y='short_version_wrap', data=use, palette=colors)
plt.title("Percentage of U.S adults who...")
plt.xlabel("")

for i, (idx, row) in enumerate(use.iterrows()):
    ax.text(row['percentage'] + 0.5, i, f"{row['percentage']:.0f}%", 
            va='center', fontsize=18)

plt.ylabel("")

plt.savefig("../plots/benchmarks.pdf", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 0.66
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_43564/1936482419.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   use['percentage'] = use['percentage'].apply(lambda x: np.round(combined * 100, 0) if x < 0 else x)
# /var/folders/4r/zf8yg_9n3qn26k_y7w56_gqr0000gp/T/ipykernel_43564/1936482419.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='percentage', y='short_version_wrap', data=use, palette=colors)

# %% [markdown]
# # Inspect weight formulas

# %%
df['recent_weight_fast'] = df['Date'].apply(lambda x: 
    np.exp(-0.01 * (pd.to_datetime("2025-7-10") - pd.to_datetime(x)).days))
sum_weight_fast = df['recent_weight_fast'].sum()
df['recent_weight_fast'] /= sum_weight_fast  # Normalize weights

df['recent_weight_slow'] = df['Date'].apply(lambda x: 
    np.exp(-0.001 * (pd.to_datetime("2025-07-10") - pd.to_datetime(x)).days))
sum_weight_slow = df['recent_weight_slow'].sum()
df['recent_weight_slow'] /= sum_weight_slow  # Normalize weights

for dv in ['recent_weight_fast', 'recent_weight_slow']:
    df[f"{dv}_cdf"] = df[dv].cumsum()

sns.lineplot(x=df['Date'], y=df['recent_weight_fast'], label='Fast Decay Weighting (alpha=0.01)', color=mypal[2])
sns.lineplot(x=df['Date'], y=df['recent_weight_slow'], label='Slow Decay Weighting (alpha=0.001)', color=mypal[3])
plt.xticks(rotation=45)
plt.ylabel("Survey Date Weight")
plt.show()
